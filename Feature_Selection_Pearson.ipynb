# %% [markdown]
# # Feature Selection Using Pearson Correlation
# Professor Mihai's recommendation to measure Pearson correlation between each feature and Grade before training models.

# %%
# Imports thus far
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
## for team: I used pearson coeefs before in another class I think it was something liken np.corrcoef(
